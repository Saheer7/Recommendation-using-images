# %%
from PIL import Image
import numpy as np
import pandas as pd

# %%
import numpy as np
import time

# %%
import os
path=os.chdir(r'E:\Capstone Project\train- Capillary 4\images')

# %%
path = "E:/Capstone Project/train- Capillary 4/images"
dirs = os.listdir( path )

def resize():
    for item in dirs:
        if i.endswith('.jpg'):
            im = Image.open(path+'/'+item)
            f, e = os.path.splitext(path+'/'+item)
            imResize = im.resize((200,200), Image.ANTIALIAS)
            imResize.save(f + ' resized.jpg', 'JPEG', quality=90)

resize()

# %%
newpath=os.chdir(r'E:\Capstone Project\train- Capillary 4\image resized')

# %%
img1 = Image.open('11139192 resized.jpg')
img2=  Image.open('11139194 resized.jpg')
img1.size,img2.size
# Out:
# ((200, 200), (200, 200))

# %%
x=np.empty([200,200,3])

# %%
images_list=[]
for image in os.listdir(newpath):
    img=Image.open(image)
    x=np.array(img)
    images_list.append(x)

# %%
images_list[0]
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#img1_arr = np.array(img1)
#img2_arr = np.array(img2)

# %%
len(images_list)
# Out:
# 3026

# %%
np.sqrt(np.sum(np.multiply(images_list[0]-images_list[1],images_list[0]-images_list[1])))
# Out:
# 2354.468729883665

# %%
distance=[]
for array in range(0,len(images_list)):
    #print(images_list[array])
    eucli=np.sqrt(np.sum((np.multiply(images_list[0],images_list[array]))))
    distance.append([eucli,images_list[array]])

# %%
distance
# Out:
# [[2305.337502406101, array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
# ...

# %%
img1 = []
for i in range(0,10):
    img=Image.fromarray(distance[i][1],'RGB')
    img1.append(img)
    for im in img1:
        im.save(path+'/'+'closest.png')

# %%
img1[6]
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x1A25AF93860>

# %%
a = img1_arr
b = img2_arr
tmp = a - b

# %%
distance=np.sum(np.multiply(tmp,tmp))
distance1=np.sum(tmp*tmp)
distance2=np.sum(tmp**2)

# %%
np.sqrt(distance)
# Out:
# 2354.468729883665

# %%
np.sqrt(distance1)
# Out:
# 4794.988946806864

# %%
np.sqrt(distance2)
# Out:
# 4794.988946806864
